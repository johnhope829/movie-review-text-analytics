# %% [markdown]
# ## Import Packages

# %%
import pandas as pd
import numpy as np
from imdb import IMDb
from concurrent.futures import ThreadPoolExecutor
from tqdm import tqdm  # Progress bar library

# %% [markdown]
# ## Read in Data

# %%
#pos_urls = pd.read_csv('../data/aclImdb/aclImdb/train/urls_pos.txt', header=None)
#neg_urls = pd.read_csv('../data/aclImdb/aclImdb/train/urls_neg.txt', header=None)
unsup_urls = pd.read_csv('../data/aclImdb/train/urls_unsup.txt', header=None)
#pd.concat([pos_urls,neg_urls,unsup_urls])

# %%
ids = [(url.split('/')[4].replace('tt',''), url) for url in unsup_urls[0].to_list()]
distinct_ids = list(set(ids))

# %% [markdown]
# ## Get TV/Movie Info

# %%
# Create an instance of the IMDb class
ia = IMDb()

# Function to get movie details with retry logic and delay
def get_movie_details(id, retries=3):
    attempt = 0
    while attempt < retries:
        try:
            # Get the movie by IMDb ID
            movie = ia.get_movie(str(id[0]))
            
            # Collect details about the movie
            movie_details = {
                "ID": id[0],
                "URL": id[1],
                "Title": movie['title'],
                "Year": movie['year'],
                "Rating": movie.get('rating', 'N/A'),
                "Genres": ", ".join(movie.get('genres', []))
            }
            
            return movie_details
        except Exception as e:
            attempt += 1
            print(f"Error for {id}: {str(e)}. Retrying ({attempt}/{retries})...")
    
    return {"Error": f"Failed to retrieve {id} after {retries} attempts."}

# List to store the results
movie_results = []

# Using ThreadPoolExecutor to parallelize with two workers
with ThreadPoolExecutor(max_workers=5) as executor:
    # Use tqdm to show progress bar while processing the IDs
    results = list(tqdm(executor.map(get_movie_details, distinct_ids), total=len(distinct_ids), desc="Processing Movies"))
    
    # Append the results to the movie_results list
    movie_results.extend(results)
# Out:
# Processing Movies:  14%|█▍        | 982/7091 [06:35<39:23,  2.58it/s]  2025-04-24 17:24:28,797 CRITICAL [imdbpy] /home/jah9kqn/.local/lib/python3.11/site-packages/imdb/_exceptions.py:32: IMDbDataAccessError exception raised; args: ({'errcode': None, 'errmsg': 'None', 'url': 'https://www.imdb.com/title/tt0112811/reference', 'proxy': '', 'exception type': 'IOError', 'original exception': TimeoutError('The read operation timed out')},); kwds: {}
# Traceback (most recent call last):
#   File "/home/jah9kqn/.local/lib/python3.11/site-packages/imdb/parser/http/__init__.py", line 233, in retrieve_unicode
#     response = uopener.open(url)
#                ^^^^^^^^^^^^^^^^^
#   File "/apps/software/standard/core/jupyterlab/3.6.3-py3.11/lib/python3.11/urllib/request.py", line 525, in open
#     response = meth(req, response)
#                ^^^^^^^^^^^^^^^^^^^
#   File "/apps/software/standard/core/jupyterlab/3.6.3-py3.11/lib/python3.11/urllib/request.py", line 634, in http_response
#     response = self.parent.error(
#                ^^^^^^^^^^^^^^^^^^
#   File "/apps/software/standard/core/jupyterlab/3.6.3-py3.11/lib/python3.11/urllib/request.py", line 557, in error
#     result = self._call_chain(*args)
#              ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/apps/software/standard/core/jupyterlab/3.6.3-py3.11/lib/python3.11/urllib/request.py", line 496, in _call_chain
#     result = func(*args)
#              ^^^^^^^^^^^
#   File "/apps/software/standard/core/jupyterlab/3.6.3-py3.11/lib/python3.11/urllib/request.py", line 749, in http_error_302
#     return self.parent.open(new, timeout=req.timeout)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/apps/software/standard/core/jupyterlab/3.6.3-py3.11/lib/python3.11/urllib/request.py", line 519, in open
#     response = self._open(req, data)
#                ^^^^^^^^^^^^^^^^^^^^^
#   File "/apps/software/standard/core/jupyterlab/3.6.3-py3.11/lib/python3.11/urllib/request.py", line 536, in _open
#     result = self._call_chain(self.handle_open, protocol, protocol +
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/apps/software/standard/core/jupyterlab/3.6.3-py3.11/lib/python3.11/urllib/request.py", line 496, in _call_chain
#     result = func(*args)
#              ^^^^^^^^^^^
#   File "/apps/software/standard/core/jupyterlab/3.6.3-py3.11/lib/python3.11/urllib/request.py", line 1391, in https_open
#     return self.do_open(http.client.HTTPSConnection, req,
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/apps/software/standard/core/jupyterlab/3.6.3-py3.11/lib/python3.11/urllib/request.py", line 1352, in do_open
#     r = h.getresponse()
#         ^^^^^^^^^^^^^^^
#   File "/apps/software/standard/core/jupyterlab/3.6.3-py3.11/lib/python3.11/http/client.py", line 1378, in getresponse
#     response.begin()
#   File "/apps/software/standard/core/jupyterlab/3.6.3-py3.11/lib/python3.11/http/client.py", line 318, in begin
#     version, status, reason = self._read_status()
#                               ^^^^^^^^^^^^^^^^^^^
#   File "/apps/software/standard/core/jupyterlab/3.6.3-py3.11/lib/python3.11/http/client.py", line 279, in _read_status
#     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/apps/software/standard/core/jupyterlab/3.6.3-py3.11/lib/python3.11/socket.py", line 706, in readinto
#     return self._sock.recv_into(b)
#            ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/apps/software/standard/core/jupyterlab/3.6.3-py3.11/lib/python3.11/ssl.py", line 1278, in recv_into
#     return self.read(nbytes, buffer)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/apps/software/standard/core/jupyterlab/3.6.3-py3.11/lib/python3.11/ssl.py", line 1134, in read
#     return self._sslobj.read(len, buffer)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# TimeoutError: The read operation timed out
# 2025-04-24 17:24:28,801 CRITICAL [imdbpy] /home/jah9kqn/.local/lib/python3.11/site-packages/imdb/__init__.py:850: caught an exception retrieving or parsing "main" info set for mopID "0112811" (accessSystem: http)
# Traceback (most recent call last):
#   File "/home/jah9kqn/.local/lib/python3.11/site-packages/imdb/parser/http/__init__.py", line 233, in retrieve_unicode
#     response = uopener.open(url)
#                ^^^^^^^^^^^^^^^^^
#   File "/apps/software/standard/core/jupyterlab/3.6.3-py3.11/lib/python3.11/urllib/request.py", line 525, in open
#     response = meth(req, response)
#                ^^^^^^^^^^^^^^^^^^^
#   File "/apps/software/standard/core/jupyterlab/3.6.3-py3.11/lib/python3.11/urllib/request.py", line 634, in http_response
#     response = self.parent.error(
#                ^^^^^^^^^^^^^^^^^^
#   File "/apps/software/standard/core/jupyterlab/3.6.3-py3.11/lib/python3.11/urllib/request.py", line 557, in error
#     result = self._call_chain(*args)
#              ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/apps/software/standard/core/jupyterlab/3.6.3-py3.11/lib/python3.11/urllib/request.py", line 496, in _call_chain
#     result = func(*args)
#              ^^^^^^^^^^^
#   File "/apps/software/standard/core/jupyterlab/3.6.3-py3.11/lib/python3.11/urllib/request.py", line 749, in http_error_302
#     return self.parent.open(new, timeout=req.timeout)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/apps/software/standard/core/jupyterlab/3.6.3-py3.11/lib/python3.11/urllib/request.py", line 519, in open
#     response = self._open(req, data)
#                ^^^^^^^^^^^^^^^^^^^^^
#   File "/apps/software/standard/core/jupyterlab/3.6.3-py3.11/lib/python3.11/urllib/request.py", line 536, in _open
#     result = self._call_chain(self.handle_open, protocol, protocol +
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/apps/software/standard/core/jupyterlab/3.6.3-py3.11/lib/python3.11/urllib/request.py", line 496, in _call_chain
#     result = func(*args)
#              ^^^^^^^^^^^
#   File "/apps/software/standard/core/jupyterlab/3.6.3-py3.11/lib/python3.11/urllib/request.py", line 1391, in https_open
#     return self.do_open(http.client.HTTPSConnection, req,
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/apps/software/standard/core/jupyterlab/3.6.3-py3.11/lib/python3.11/urllib/request.py", line 1352, in do_open
#     r = h.getresponse()
#         ^^^^^^^^^^^^^^^
#   File "/apps/software/standard/core/jupyterlab/3.6.3-py3.11/lib/python3.11/http/client.py", line 1378, in getresponse
#     response.begin()
#   File "/apps/software/standard/core/jupyterlab/3.6.3-py3.11/lib/python3.11/http/client.py", line 318, in begin
#     version, status, reason = self._read_status()
#                               ^^^^^^^^^^^^^^^^^^^
#   File "/apps/software/standard/core/jupyterlab/3.6.3-py3.11/lib/python3.11/http/client.py", line 279, in _read_status
#     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/apps/software/standard/core/jupyterlab/3.6.3-py3.11/lib/python3.11/socket.py", line 706, in readinto
#     return self._sock.recv_into(b)
#            ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/apps/software/standard/core/jupyterlab/3.6.3-py3.11/lib/python3.11/ssl.py", line 1278, in recv_into
#     return self.read(nbytes, buffer)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/apps/software/standard/core/jupyterlab/3.6.3-py3.11/lib/python3.11/ssl.py", line 1134, in read
#     return self._sslobj.read(len, buffer)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# TimeoutError: The read operation timed out
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/jah9kqn/.local/lib/python3.11/site-packages/imdb/__init__.py", line 848, in update
#     ret = method(mopID)
#           ^^^^^^^^^^^^^
#   File "/home/jah9kqn/.local/lib/python3.11/site-packages/imdb/parser/http/__init__.py", line 481, in get_movie_main
#     cont = self._retrieve(self.urls['movie_main'] % movieID + 'reference')
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/jah9kqn/.local/lib/python3.11/site-packages/imdb/parser/http/__init__.py", line 392, in _retrieve
#     ret = self.urlOpener.retrieve_unicode(url, size=size)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/jah9kqn/.local/lib/python3.11/site-packages/imdb/parser/http/__init__.py", line 261, in retrieve_unicode
#     raise IMDbDataAccessError(
# imdb._exceptions.IMDbDataAccessError: {'errcode': None, 'errmsg': 'None', 'url': 'https://www.imdb.com/title/tt0112811/reference', 'proxy': '', 'exception type': 'IOError', 'original exception': TimeoutError('The read operation timed out')}
# Error for ('0112811', 'http://www.imdb.com/title/tt0112811/usercomments'): {'errcode': None, 'errmsg': 'None', 'url': 'https://www.imdb.com/title/tt0112811/reference', 'proxy': '', 'exception type': 'IOError', 'original exception': TimeoutError('The read operation timed out')}. Retrying (1/3)...
# Processing Movies:  52%|█████▏    | 3667/7091 [24:55<22:40,  2.52it/s]  2025-04-24 17:42:49,210 CRITICAL [imdbpy] /home/jah9kqn/.local/lib/python3.11/site-packages/imdb/_exceptions.py:32: IMDbDataAccessError exception raised; args: ({'errcode': None, 'errmsg': 'None', 'url': 'https://www.imdb.com/title/tt0177469/reference', 'proxy': '', 'exception type': 'IOError', 'original exception': TimeoutError('The read operation timed out')},); kwds: {}
# Traceback (most recent call last):
#   File "/home/jah9kqn/.local/lib/python3.11/site-packages/imdb/parser/http/__init__.py", line 233, in retrieve_unicode
#     response = uopener.open(url)
#                ^^^^^^^^^^^^^^^^^
#   File "/apps/software/standard/core/jupyterlab/3.6.3-py3.11/lib/python3.11/urllib/request.py", line 525, in open
#     response = meth(req, response)
#                ^^^^^^^^^^^^^^^^^^^
#   File "/apps/software/standard/core/jupyterlab/3.6.3-py3.11/lib/python3.11/urllib/request.py", line 634, in http_response
#     response = self.parent.error(
#                ^^^^^^^^^^^^^^^^^^
#   File "/apps/software/standard/core/jupyterlab/3.6.3-py3.11/lib/python3.11/urllib/request.py", line 557, in error
#     result = self._call_chain(*args)
#              ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/apps/software/standard/core/jupyterlab/3.6.3-py3.11/lib/python3.11/urllib/request.py", line 496, in _call_chain
#     result = func(*args)
#              ^^^^^^^^^^^
#   File "/apps/software/standard/core/jupyterlab/3.6.3-py3.11/lib/python3.11/urllib/request.py", line 749, in http_error_302
#     return self.parent.open(new, timeout=req.timeout)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/apps/software/standard/core/jupyterlab/3.6.3-py3.11/lib/python3.11/urllib/request.py", line 519, in open
#     response = self._open(req, data)
#                ^^^^^^^^^^^^^^^^^^^^^
#   File "/apps/software/standard/core/jupyterlab/3.6.3-py3.11/lib/python3.11/urllib/request.py", line 536, in _open
#     result = self._call_chain(self.handle_open, protocol, protocol +
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/apps/software/standard/core/jupyterlab/3.6.3-py3.11/lib/python3.11/urllib/request.py", line 496, in _call_chain
#     result = func(*args)
#              ^^^^^^^^^^^
#   File "/apps/software/standard/core/jupyterlab/3.6.3-py3.11/lib/python3.11/urllib/request.py", line 1391, in https_open
#     return self.do_open(http.client.HTTPSConnection, req,
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/apps/software/standard/core/jupyterlab/3.6.3-py3.11/lib/python3.11/urllib/request.py", line 1352, in do_open
#     r = h.getresponse()
#         ^^^^^^^^^^^^^^^
#   File "/apps/software/standard/core/jupyterlab/3.6.3-py3.11/lib/python3.11/http/client.py", line 1378, in getresponse
#     response.begin()
#   File "/apps/software/standard/core/jupyterlab/3.6.3-py3.11/lib/python3.11/http/client.py", line 318, in begin
#     version, status, reason = self._read_status()
#                               ^^^^^^^^^^^^^^^^^^^
#   File "/apps/software/standard/core/jupyterlab/3.6.3-py3.11/lib/python3.11/http/client.py", line 279, in _read_status
#     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/apps/software/standard/core/jupyterlab/3.6.3-py3.11/lib/python3.11/socket.py", line 706, in readinto
#     return self._sock.recv_into(b)
#            ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/apps/software/standard/core/jupyterlab/3.6.3-py3.11/lib/python3.11/ssl.py", line 1278, in recv_into
#     return self.read(nbytes, buffer)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/apps/software/standard/core/jupyterlab/3.6.3-py3.11/lib/python3.11/ssl.py", line 1134, in read
#     return self._sslobj.read(len, buffer)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# TimeoutError: The read operation timed out
# 2025-04-24 17:42:49,212 CRITICAL [imdbpy] /home/jah9kqn/.local/lib/python3.11/site-packages/imdb/__init__.py:850: caught an exception retrieving or parsing "main" info set for mopID "0177469" (accessSystem: http)
# Traceback (most recent call last):
#   File "/home/jah9kqn/.local/lib/python3.11/site-packages/imdb/parser/http/__init__.py", line 233, in retrieve_unicode
#     response = uopener.open(url)
#                ^^^^^^^^^^^^^^^^^
#   File "/apps/software/standard/core/jupyterlab/3.6.3-py3.11/lib/python3.11/urllib/request.py", line 525, in open
#     response = meth(req, response)
#                ^^^^^^^^^^^^^^^^^^^
#   File "/apps/software/standard/core/jupyterlab/3.6.3-py3.11/lib/python3.11/urllib/request.py", line 634, in http_response
#     response = self.parent.error(
#                ^^^^^^^^^^^^^^^^^^
#   File "/apps/software/standard/core/jupyterlab/3.6.3-py3.11/lib/python3.11/urllib/request.py", line 557, in error
#     result = self._call_chain(*args)
#              ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/apps/software/standard/core/jupyterlab/3.6.3-py3.11/lib/python3.11/urllib/request.py", line 496, in _call_chain
#     result = func(*args)
#              ^^^^^^^^^^^
#   File "/apps/software/standard/core/jupyterlab/3.6.3-py3.11/lib/python3.11/urllib/request.py", line 749, in http_error_302
#     return self.parent.open(new, timeout=req.timeout)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/apps/software/standard/core/jupyterlab/3.6.3-py3.11/lib/python3.11/urllib/request.py", line 519, in open
#     response = self._open(req, data)
#                ^^^^^^^^^^^^^^^^^^^^^
#   File "/apps/software/standard/core/jupyterlab/3.6.3-py3.11/lib/python3.11/urllib/request.py", line 536, in _open
#     result = self._call_chain(self.handle_open, protocol, protocol +
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/apps/software/standard/core/jupyterlab/3.6.3-py3.11/lib/python3.11/urllib/request.py", line 496, in _call_chain
#     result = func(*args)
#              ^^^^^^^^^^^
#   File "/apps/software/standard/core/jupyterlab/3.6.3-py3.11/lib/python3.11/urllib/request.py", line 1391, in https_open
#     return self.do_open(http.client.HTTPSConnection, req,
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/apps/software/standard/core/jupyterlab/3.6.3-py3.11/lib/python3.11/urllib/request.py", line 1352, in do_open
#     r = h.getresponse()
#         ^^^^^^^^^^^^^^^
#   File "/apps/software/standard/core/jupyterlab/3.6.3-py3.11/lib/python3.11/http/client.py", line 1378, in getresponse
#     response.begin()
#   File "/apps/software/standard/core/jupyterlab/3.6.3-py3.11/lib/python3.11/http/client.py", line 318, in begin
#     version, status, reason = self._read_status()
#                               ^^^^^^^^^^^^^^^^^^^
#   File "/apps/software/standard/core/jupyterlab/3.6.3-py3.11/lib/python3.11/http/client.py", line 279, in _read_status
#     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/apps/software/standard/core/jupyterlab/3.6.3-py3.11/lib/python3.11/socket.py", line 706, in readinto
#     return self._sock.recv_into(b)
#            ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/apps/software/standard/core/jupyterlab/3.6.3-py3.11/lib/python3.11/ssl.py", line 1278, in recv_into
#     return self.read(nbytes, buffer)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/apps/software/standard/core/jupyterlab/3.6.3-py3.11/lib/python3.11/ssl.py", line 1134, in read
#     return self._sslobj.read(len, buffer)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# TimeoutError: The read operation timed out
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/jah9kqn/.local/lib/python3.11/site-packages/imdb/__init__.py", line 848, in update
#     ret = method(mopID)
#           ^^^^^^^^^^^^^
#   File "/home/jah9kqn/.local/lib/python3.11/site-packages/imdb/parser/http/__init__.py", line 481, in get_movie_main
#     cont = self._retrieve(self.urls['movie_main'] % movieID + 'reference')
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/jah9kqn/.local/lib/python3.11/site-packages/imdb/parser/http/__init__.py", line 392, in _retrieve
#     ret = self.urlOpener.retrieve_unicode(url, size=size)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/jah9kqn/.local/lib/python3.11/site-packages/imdb/parser/http/__init__.py", line 261, in retrieve_unicode
#     raise IMDbDataAccessError(
# imdb._exceptions.IMDbDataAccessError: {'errcode': None, 'errmsg': 'None', 'url': 'https://www.imdb.com/title/tt0177469/reference', 'proxy': '', 'exception type': 'IOError', 'original exception': TimeoutError('The read operation timed out')}
# Error for ('0177469', 'http://www.imdb.com/title/tt0177469/usercomments'): {'errcode': None, 'errmsg': 'None', 'url': 'https://www.imdb.com/title/tt0177469/reference', 'proxy': '', 'exception type': 'IOError', 'original exception': TimeoutError('The read operation timed out')}. Retrying (1/3)...
# Processing Movies:  80%|████████  | 5698/7091 [39:03<09:18,  2.49it/s]  2025-04-24 17:56:56,969 CRITICAL [imdbpy] /home/jah9kqn/.local/lib/python3.11/site-packages/imdb/_exceptions.py:32: IMDbDataAccessError exception raised; args: ({'errcode': None, 'errmsg': 'None', 'url': 'https://www.imdb.com/title/tt0105984/reference', 'proxy': '', 'exception type': 'IOError', 'original exception': TimeoutError('The read operation timed out')},); kwds: {}
# Traceback (most recent call last):
#   File "/home/jah9kqn/.local/lib/python3.11/site-packages/imdb/parser/http/__init__.py", line 233, in retrieve_unicode
#     response = uopener.open(url)
#                ^^^^^^^^^^^^^^^^^
#   File "/apps/software/standard/core/jupyterlab/3.6.3-py3.11/lib/python3.11/urllib/request.py", line 525, in open
#     response = meth(req, response)
#                ^^^^^^^^^^^^^^^^^^^
#   File "/apps/software/standard/core/jupyterlab/3.6.3-py3.11/lib/python3.11/urllib/request.py", line 634, in http_response
#     response = self.parent.error(
#                ^^^^^^^^^^^^^^^^^^
#   File "/apps/software/standard/core/jupyterlab/3.6.3-py3.11/lib/python3.11/urllib/request.py", line 557, in error
#     result = self._call_chain(*args)
#              ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/apps/software/standard/core/jupyterlab/3.6.3-py3.11/lib/python3.11/urllib/request.py", line 496, in _call_chain
#     result = func(*args)
#              ^^^^^^^^^^^
#   File "/apps/software/standard/core/jupyterlab/3.6.3-py3.11/lib/python3.11/urllib/request.py", line 749, in http_error_302
#     return self.parent.open(new, timeout=req.timeout)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/apps/software/standard/core/jupyterlab/3.6.3-py3.11/lib/python3.11/urllib/request.py", line 519, in open
#     response = self._open(req, data)
#                ^^^^^^^^^^^^^^^^^^^^^
#   File "/apps/software/standard/core/jupyterlab/3.6.3-py3.11/lib/python3.11/urllib/request.py", line 536, in _open
#     result = self._call_chain(self.handle_open, protocol, protocol +
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/apps/software/standard/core/jupyterlab/3.6.3-py3.11/lib/python3.11/urllib/request.py", line 496, in _call_chain
#     result = func(*args)
#              ^^^^^^^^^^^
#   File "/apps/software/standard/core/jupyterlab/3.6.3-py3.11/lib/python3.11/urllib/request.py", line 1391, in https_open
#     return self.do_open(http.client.HTTPSConnection, req,
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/apps/software/standard/core/jupyterlab/3.6.3-py3.11/lib/python3.11/urllib/request.py", line 1352, in do_open
#     r = h.getresponse()
#         ^^^^^^^^^^^^^^^
#   File "/apps/software/standard/core/jupyterlab/3.6.3-py3.11/lib/python3.11/http/client.py", line 1378, in getresponse
#     response.begin()
#   File "/apps/software/standard/core/jupyterlab/3.6.3-py3.11/lib/python3.11/http/client.py", line 318, in begin
#     version, status, reason = self._read_status()
#                               ^^^^^^^^^^^^^^^^^^^
#   File "/apps/software/standard/core/jupyterlab/3.6.3-py3.11/lib/python3.11/http/client.py", line 279, in _read_status
#     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/apps/software/standard/core/jupyterlab/3.6.3-py3.11/lib/python3.11/socket.py", line 706, in readinto
#     return self._sock.recv_into(b)
#            ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/apps/software/standard/core/jupyterlab/3.6.3-py3.11/lib/python3.11/ssl.py", line 1278, in recv_into
#     return self.read(nbytes, buffer)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/apps/software/standard/core/jupyterlab/3.6.3-py3.11/lib/python3.11/ssl.py", line 1134, in read
#     return self._sslobj.read(len, buffer)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# TimeoutError: The read operation timed out
# 2025-04-24 17:56:56,971 CRITICAL [imdbpy] /home/jah9kqn/.local/lib/python3.11/site-packages/imdb/__init__.py:850: caught an exception retrieving or parsing "main" info set for mopID "0105984" (accessSystem: http)
# Traceback (most recent call last):
#   File "/home/jah9kqn/.local/lib/python3.11/site-packages/imdb/parser/http/__init__.py", line 233, in retrieve_unicode
#     response = uopener.open(url)
#                ^^^^^^^^^^^^^^^^^
#   File "/apps/software/standard/core/jupyterlab/3.6.3-py3.11/lib/python3.11/urllib/request.py", line 525, in open
#     response = meth(req, response)
#                ^^^^^^^^^^^^^^^^^^^
#   File "/apps/software/standard/core/jupyterlab/3.6.3-py3.11/lib/python3.11/urllib/request.py", line 634, in http_response
#     response = self.parent.error(
#                ^^^^^^^^^^^^^^^^^^
#   File "/apps/software/standard/core/jupyterlab/3.6.3-py3.11/lib/python3.11/urllib/request.py", line 557, in error
#     result = self._call_chain(*args)
#              ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/apps/software/standard/core/jupyterlab/3.6.3-py3.11/lib/python3.11/urllib/request.py", line 496, in _call_chain
#     result = func(*args)
#              ^^^^^^^^^^^
#   File "/apps/software/standard/core/jupyterlab/3.6.3-py3.11/lib/python3.11/urllib/request.py", line 749, in http_error_302
#     return self.parent.open(new, timeout=req.timeout)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/apps/software/standard/core/jupyterlab/3.6.3-py3.11/lib/python3.11/urllib/request.py", line 519, in open
#     response = self._open(req, data)
#                ^^^^^^^^^^^^^^^^^^^^^
#   File "/apps/software/standard/core/jupyterlab/3.6.3-py3.11/lib/python3.11/urllib/request.py", line 536, in _open
#     result = self._call_chain(self.handle_open, protocol, protocol +
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/apps/software/standard/core/jupyterlab/3.6.3-py3.11/lib/python3.11/urllib/request.py", line 496, in _call_chain
#     result = func(*args)
#              ^^^^^^^^^^^
#   File "/apps/software/standard/core/jupyterlab/3.6.3-py3.11/lib/python3.11/urllib/request.py", line 1391, in https_open
#     return self.do_open(http.client.HTTPSConnection, req,
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/apps/software/standard/core/jupyterlab/3.6.3-py3.11/lib/python3.11/urllib/request.py", line 1352, in do_open
#     r = h.getresponse()
#         ^^^^^^^^^^^^^^^
#   File "/apps/software/standard/core/jupyterlab/3.6.3-py3.11/lib/python3.11/http/client.py", line 1378, in getresponse
#     response.begin()
#   File "/apps/software/standard/core/jupyterlab/3.6.3-py3.11/lib/python3.11/http/client.py", line 318, in begin
#     version, status, reason = self._read_status()
#                               ^^^^^^^^^^^^^^^^^^^
#   File "/apps/software/standard/core/jupyterlab/3.6.3-py3.11/lib/python3.11/http/client.py", line 279, in _read_status
#     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/apps/software/standard/core/jupyterlab/3.6.3-py3.11/lib/python3.11/socket.py", line 706, in readinto
#     return self._sock.recv_into(b)
#            ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/apps/software/standard/core/jupyterlab/3.6.3-py3.11/lib/python3.11/ssl.py", line 1278, in recv_into
#     return self.read(nbytes, buffer)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/apps/software/standard/core/jupyterlab/3.6.3-py3.11/lib/python3.11/ssl.py", line 1134, in read
#     return self._sslobj.read(len, buffer)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# TimeoutError: The read operation timed out
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/jah9kqn/.local/lib/python3.11/site-packages/imdb/__init__.py", line 848, in update
#     ret = method(mopID)
#           ^^^^^^^^^^^^^
#   File "/home/jah9kqn/.local/lib/python3.11/site-packages/imdb/parser/http/__init__.py", line 481, in get_movie_main
#     cont = self._retrieve(self.urls['movie_main'] % movieID + 'reference')
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/jah9kqn/.local/lib/python3.11/site-packages/imdb/parser/http/__init__.py", line 392, in _retrieve
#     ret = self.urlOpener.retrieve_unicode(url, size=size)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/jah9kqn/.local/lib/python3.11/site-packages/imdb/parser/http/__init__.py", line 261, in retrieve_unicode
#     raise IMDbDataAccessError(
# imdb._exceptions.IMDbDataAccessError: {'errcode': None, 'errmsg': 'None', 'url': 'https://www.imdb.com/title/tt0105984/reference', 'proxy': '', 'exception type': 'IOError', 'original exception': TimeoutError('The read operation timed out')}
# Error for ('0105984', 'http://www.imdb.com/title/tt0105984/usercomments'): {'errcode': None, 'errmsg': 'None', 'url': 'https://www.imdb.com/title/tt0105984/reference', 'proxy': '', 'exception type': 'IOError', 'original exception': TimeoutError('The read operation timed out')}. Retrying (1/3)...
# Processing Movies:  91%|█████████▏| 6485/7091 [44:32<04:23,  2.30it/s]  2025-04-24 18:02:25,794 CRITICAL [imdbpy] /home/jah9kqn/.local/lib/python3.11/site-packages/imdb/_exceptions.py:32: IMDbDataAccessError exception raised; args: ({'errcode': None, 'errmsg': 'None', 'url': 'https://www.imdb.com/title/tt0088580/reference', 'proxy': '', 'exception type': 'IOError', 'original exception': TimeoutError('The read operation timed out')},); kwds: {}
# Traceback (most recent call last):
#   File "/home/jah9kqn/.local/lib/python3.11/site-packages/imdb/parser/http/__init__.py", line 233, in retrieve_unicode
#     response = uopener.open(url)
#                ^^^^^^^^^^^^^^^^^
#   File "/apps/software/standard/core/jupyterlab/3.6.3-py3.11/lib/python3.11/urllib/request.py", line 519, in open
#     response = self._open(req, data)
#                ^^^^^^^^^^^^^^^^^^^^^
#   File "/apps/software/standard/core/jupyterlab/3.6.3-py3.11/lib/python3.11/urllib/request.py", line 536, in _open
#     result = self._call_chain(self.handle_open, protocol, protocol +
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/apps/software/standard/core/jupyterlab/3.6.3-py3.11/lib/python3.11/urllib/request.py", line 496, in _call_chain
#     result = func(*args)
#              ^^^^^^^^^^^
#   File "/apps/software/standard/core/jupyterlab/3.6.3-py3.11/lib/python3.11/urllib/request.py", line 1391, in https_open
#     return self.do_open(http.client.HTTPSConnection, req,
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/apps/software/standard/core/jupyterlab/3.6.3-py3.11/lib/python3.11/urllib/request.py", line 1352, in do_open
#     r = h.getresponse()
#         ^^^^^^^^^^^^^^^
#   File "/apps/software/standard/core/jupyterlab/3.6.3-py3.11/lib/python3.11/http/client.py", line 1378, in getresponse
#     response.begin()
#   File "/apps/software/standard/core/jupyterlab/3.6.3-py3.11/lib/python3.11/http/client.py", line 318, in begin
#     version, status, reason = self._read_status()
#                               ^^^^^^^^^^^^^^^^^^^
#   File "/apps/software/standard/core/jupyterlab/3.6.3-py3.11/lib/python3.11/http/client.py", line 279, in _read_status
#     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/apps/software/standard/core/jupyterlab/3.6.3-py3.11/lib/python3.11/socket.py", line 706, in readinto
#     return self._sock.recv_into(b)
#            ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/apps/software/standard/core/jupyterlab/3.6.3-py3.11/lib/python3.11/ssl.py", line 1278, in recv_into
#     return self.read(nbytes, buffer)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/apps/software/standard/core/jupyterlab/3.6.3-py3.11/lib/python3.11/ssl.py", line 1134, in read
#     return self._sslobj.read(len, buffer)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# TimeoutError: The read operation timed out
# 2025-04-24 18:02:25,797 CRITICAL [imdbpy] /home/jah9kqn/.local/lib/python3.11/site-packages/imdb/__init__.py:850: caught an exception retrieving or parsing "main" info set for mopID "0088580" (accessSystem: http)
# Traceback (most recent call last):
#   File "/home/jah9kqn/.local/lib/python3.11/site-packages/imdb/parser/http/__init__.py", line 233, in retrieve_unicode
#     response = uopener.open(url)
#                ^^^^^^^^^^^^^^^^^
#   File "/apps/software/standard/core/jupyterlab/3.6.3-py3.11/lib/python3.11/urllib/request.py", line 519, in open
#     response = self._open(req, data)
#                ^^^^^^^^^^^^^^^^^^^^^
#   File "/apps/software/standard/core/jupyterlab/3.6.3-py3.11/lib/python3.11/urllib/request.py", line 536, in _open
#     result = self._call_chain(self.handle_open, protocol, protocol +
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/apps/software/standard/core/jupyterlab/3.6.3-py3.11/lib/python3.11/urllib/request.py", line 496, in _call_chain
#     result = func(*args)
#              ^^^^^^^^^^^
#   File "/apps/software/standard/core/jupyterlab/3.6.3-py3.11/lib/python3.11/urllib/request.py", line 1391, in https_open
#     return self.do_open(http.client.HTTPSConnection, req,
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/apps/software/standard/core/jupyterlab/3.6.3-py3.11/lib/python3.11/urllib/request.py", line 1352, in do_open
#     r = h.getresponse()
#         ^^^^^^^^^^^^^^^
#   File "/apps/software/standard/core/jupyterlab/3.6.3-py3.11/lib/python3.11/http/client.py", line 1378, in getresponse
#     response.begin()
#   File "/apps/software/standard/core/jupyterlab/3.6.3-py3.11/lib/python3.11/http/client.py", line 318, in begin
#     version, status, reason = self._read_status()
#                               ^^^^^^^^^^^^^^^^^^^
#   File "/apps/software/standard/core/jupyterlab/3.6.3-py3.11/lib/python3.11/http/client.py", line 279, in _read_status
#     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/apps/software/standard/core/jupyterlab/3.6.3-py3.11/lib/python3.11/socket.py", line 706, in readinto
#     return self._sock.recv_into(b)
#            ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/apps/software/standard/core/jupyterlab/3.6.3-py3.11/lib/python3.11/ssl.py", line 1278, in recv_into
#     return self.read(nbytes, buffer)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/apps/software/standard/core/jupyterlab/3.6.3-py3.11/lib/python3.11/ssl.py", line 1134, in read
#     return self._sslobj.read(len, buffer)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# TimeoutError: The read operation timed out
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/jah9kqn/.local/lib/python3.11/site-packages/imdb/__init__.py", line 848, in update
#     ret = method(mopID)
#           ^^^^^^^^^^^^^
#   File "/home/jah9kqn/.local/lib/python3.11/site-packages/imdb/parser/http/__init__.py", line 481, in get_movie_main
#     cont = self._retrieve(self.urls['movie_main'] % movieID + 'reference')
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/jah9kqn/.local/lib/python3.11/site-packages/imdb/parser/http/__init__.py", line 392, in _retrieve
#     ret = self.urlOpener.retrieve_unicode(url, size=size)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/jah9kqn/.local/lib/python3.11/site-packages/imdb/parser/http/__init__.py", line 261, in retrieve_unicode
#     raise IMDbDataAccessError(
# imdb._exceptions.IMDbDataAccessError: {'errcode': None, 'errmsg': 'None', 'url': 'https://www.imdb.com/title/tt0088580/reference', 'proxy': '', 'exception type': 'IOError', 'original exception': TimeoutError('The read operation timed out')}
# Error for ('0088580', 'http://www.imdb.com/title/tt0088580/usercomments'): {'errcode': None, 'errmsg': 'None', 'url': 'https://www.imdb.com/title/tt0088580/reference', 'proxy': '', 'exception type': 'IOError', 'original exception': TimeoutError('The read operation timed out')}. Retrying (1/3)...
# 2025-04-24 18:02:55,843 CRITICAL [imdbpy] /home/jah9kqn/.local/lib/python3.11/site-packages/imdb/_exceptions.py:32: IMDbDataAccessError exception raised; args: ({'errcode': None, 'errmsg': 'None', 'url': 'https://www.imdb.com/title/tt0088580/reference', 'proxy': '', 'exception type': 'IOError', 'original exception': TimeoutError('The read operation timed out')},); kwds: {}
# Traceback (most recent call last):
#   File "/home/jah9kqn/.local/lib/python3.11/site-packages/imdb/parser/http/__init__.py", line 233, in retrieve_unicode
#     response = uopener.open(url)
#                ^^^^^^^^^^^^^^^^^
#   File "/apps/software/standard/core/jupyterlab/3.6.3-py3.11/lib/python3.11/urllib/request.py", line 519, in open
#     response = self._open(req, data)
#                ^^^^^^^^^^^^^^^^^^^^^
#   File "/apps/software/standard/core/jupyterlab/3.6.3-py3.11/lib/python3.11/urllib/request.py", line 536, in _open
#     result = self._call_chain(self.handle_open, protocol, protocol +
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/apps/software/standard/core/jupyterlab/3.6.3-py3.11/lib/python3.11/urllib/request.py", line 496, in _call_chain
#     result = func(*args)
#              ^^^^^^^^^^^
#   File "/apps/software/standard/core/jupyterlab/3.6.3-py3.11/lib/python3.11/urllib/request.py", line 1391, in https_open
#     return self.do_open(http.client.HTTPSConnection, req,
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/apps/software/standard/core/jupyterlab/3.6.3-py3.11/lib/python3.11/urllib/request.py", line 1352, in do_open
#     r = h.getresponse()
#         ^^^^^^^^^^^^^^^
#   File "/apps/software/standard/core/jupyterlab/3.6.3-py3.11/lib/python3.11/http/client.py", line 1378, in getresponse
#     response.begin()
#   File "/apps/software/standard/core/jupyterlab/3.6.3-py3.11/lib/python3.11/http/client.py", line 318, in begin
#     version, status, reason = self._read_status()
#                               ^^^^^^^^^^^^^^^^^^^
#   File "/apps/software/standard/core/jupyterlab/3.6.3-py3.11/lib/python3.11/http/client.py", line 279, in _read_status
#     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/apps/software/standard/core/jupyterlab/3.6.3-py3.11/lib/python3.11/socket.py", line 706, in readinto
#     return self._sock.recv_into(b)
#            ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/apps/software/standard/core/jupyterlab/3.6.3-py3.11/lib/python3.11/ssl.py", line 1278, in recv_into
#     return self.read(nbytes, buffer)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/apps/software/standard/core/jupyterlab/3.6.3-py3.11/lib/python3.11/ssl.py", line 1134, in read
#     return self._sslobj.read(len, buffer)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# TimeoutError: The read operation timed out
# 2025-04-24 18:02:55,845 CRITICAL [imdbpy] /home/jah9kqn/.local/lib/python3.11/site-packages/imdb/__init__.py:850: caught an exception retrieving or parsing "main" info set for mopID "0088580" (accessSystem: http)
# Traceback (most recent call last):
#   File "/home/jah9kqn/.local/lib/python3.11/site-packages/imdb/parser/http/__init__.py", line 233, in retrieve_unicode
#     response = uopener.open(url)
#                ^^^^^^^^^^^^^^^^^
#   File "/apps/software/standard/core/jupyterlab/3.6.3-py3.11/lib/python3.11/urllib/request.py", line 519, in open
#     response = self._open(req, data)
#                ^^^^^^^^^^^^^^^^^^^^^
#   File "/apps/software/standard/core/jupyterlab/3.6.3-py3.11/lib/python3.11/urllib/request.py", line 536, in _open
#     result = self._call_chain(self.handle_open, protocol, protocol +
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/apps/software/standard/core/jupyterlab/3.6.3-py3.11/lib/python3.11/urllib/request.py", line 496, in _call_chain
#     result = func(*args)
#              ^^^^^^^^^^^
#   File "/apps/software/standard/core/jupyterlab/3.6.3-py3.11/lib/python3.11/urllib/request.py", line 1391, in https_open
#     return self.do_open(http.client.HTTPSConnection, req,
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/apps/software/standard/core/jupyterlab/3.6.3-py3.11/lib/python3.11/urllib/request.py", line 1352, in do_open
#     r = h.getresponse()
#         ^^^^^^^^^^^^^^^
#   File "/apps/software/standard/core/jupyterlab/3.6.3-py3.11/lib/python3.11/http/client.py", line 1378, in getresponse
#     response.begin()
#   File "/apps/software/standard/core/jupyterlab/3.6.3-py3.11/lib/python3.11/http/client.py", line 318, in begin
#     version, status, reason = self._read_status()
#                               ^^^^^^^^^^^^^^^^^^^
#   File "/apps/software/standard/core/jupyterlab/3.6.3-py3.11/lib/python3.11/http/client.py", line 279, in _read_status
#     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/apps/software/standard/core/jupyterlab/3.6.3-py3.11/lib/python3.11/socket.py", line 706, in readinto
#     return self._sock.recv_into(b)
#            ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/apps/software/standard/core/jupyterlab/3.6.3-py3.11/lib/python3.11/ssl.py", line 1278, in recv_into
#     return self.read(nbytes, buffer)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/apps/software/standard/core/jupyterlab/3.6.3-py3.11/lib/python3.11/ssl.py", line 1134, in read
#     return self._sslobj.read(len, buffer)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# TimeoutError: The read operation timed out
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/jah9kqn/.local/lib/python3.11/site-packages/imdb/__init__.py", line 848, in update
#     ret = method(mopID)
#           ^^^^^^^^^^^^^
#   File "/home/jah9kqn/.local/lib/python3.11/site-packages/imdb/parser/http/__init__.py", line 481, in get_movie_main
#     cont = self._retrieve(self.urls['movie_main'] % movieID + 'reference')
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/jah9kqn/.local/lib/python3.11/site-packages/imdb/parser/http/__init__.py", line 392, in _retrieve
#     ret = self.urlOpener.retrieve_unicode(url, size=size)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/jah9kqn/.local/lib/python3.11/site-packages/imdb/parser/http/__init__.py", line 261, in retrieve_unicode
#     raise IMDbDataAccessError(
# imdb._exceptions.IMDbDataAccessError: {'errcode': None, 'errmsg': 'None', 'url': 'https://www.imdb.com/title/tt0088580/reference', 'proxy': '', 'exception type': 'IOError', 'original exception': TimeoutError('The read operation timed out')}
# Error for ('0088580', 'http://www.imdb.com/title/tt0088580/usercomments'): {'errcode': None, 'errmsg': 'None', 'url': 'https://www.imdb.com/title/tt0088580/reference', 'proxy': '', 'exception type': 'IOError', 'original exception': TimeoutError('The read operation timed out')}. Retrying (2/3)...
# 2025-04-24 18:03:25,890 CRITICAL [imdbpy] /home/jah9kqn/.local/lib/python3.11/site-packages/imdb/_exceptions.py:32: IMDbDataAccessError exception raised; args: ({'errcode': None, 'errmsg': 'None', 'url': 'https://www.imdb.com/title/tt0088580/reference', 'proxy': '', 'exception type': 'IOError', 'original exception': TimeoutError('The read operation timed out')},); kwds: {}
# Traceback (most recent call last):
#   File "/home/jah9kqn/.local/lib/python3.11/site-packages/imdb/parser/http/__init__.py", line 233, in retrieve_unicode
#     response = uopener.open(url)
#                ^^^^^^^^^^^^^^^^^
#   File "/apps/software/standard/core/jupyterlab/3.6.3-py3.11/lib/python3.11/urllib/request.py", line 519, in open
#     response = self._open(req, data)
#                ^^^^^^^^^^^^^^^^^^^^^
#   File "/apps/software/standard/core/jupyterlab/3.6.3-py3.11/lib/python3.11/urllib/request.py", line 536, in _open
#     result = self._call_chain(self.handle_open, protocol, protocol +
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/apps/software/standard/core/jupyterlab/3.6.3-py3.11/lib/python3.11/urllib/request.py", line 496, in _call_chain
#     result = func(*args)
#              ^^^^^^^^^^^
#   File "/apps/software/standard/core/jupyterlab/3.6.3-py3.11/lib/python3.11/urllib/request.py", line 1391, in https_open
#     return self.do_open(http.client.HTTPSConnection, req,
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/apps/software/standard/core/jupyterlab/3.6.3-py3.11/lib/python3.11/urllib/request.py", line 1352, in do_open
#     r = h.getresponse()
#         ^^^^^^^^^^^^^^^
#   File "/apps/software/standard/core/jupyterlab/3.6.3-py3.11/lib/python3.11/http/client.py", line 1378, in getresponse
#     response.begin()
#   File "/apps/software/standard/core/jupyterlab/3.6.3-py3.11/lib/python3.11/http/client.py", line 318, in begin
#     version, status, reason = self._read_status()
#                               ^^^^^^^^^^^^^^^^^^^
#   File "/apps/software/standard/core/jupyterlab/3.6.3-py3.11/lib/python3.11/http/client.py", line 279, in _read_status
#     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/apps/software/standard/core/jupyterlab/3.6.3-py3.11/lib/python3.11/socket.py", line 706, in readinto
#     return self._sock.recv_into(b)
#            ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/apps/software/standard/core/jupyterlab/3.6.3-py3.11/lib/python3.11/ssl.py", line 1278, in recv_into
#     return self.read(nbytes, buffer)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/apps/software/standard/core/jupyterlab/3.6.3-py3.11/lib/python3.11/ssl.py", line 1134, in read
#     return self._sslobj.read(len, buffer)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# TimeoutError: The read operation timed out
# 2025-04-24 18:03:25,892 CRITICAL [imdbpy] /home/jah9kqn/.local/lib/python3.11/site-packages/imdb/__init__.py:850: caught an exception retrieving or parsing "main" info set for mopID "0088580" (accessSystem: http)
# Traceback (most recent call last):
#   File "/home/jah9kqn/.local/lib/python3.11/site-packages/imdb/parser/http/__init__.py", line 233, in retrieve_unicode
#     response = uopener.open(url)
#                ^^^^^^^^^^^^^^^^^
#   File "/apps/software/standard/core/jupyterlab/3.6.3-py3.11/lib/python3.11/urllib/request.py", line 519, in open
#     response = self._open(req, data)
#                ^^^^^^^^^^^^^^^^^^^^^
#   File "/apps/software/standard/core/jupyterlab/3.6.3-py3.11/lib/python3.11/urllib/request.py", line 536, in _open
#     result = self._call_chain(self.handle_open, protocol, protocol +
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/apps/software/standard/core/jupyterlab/3.6.3-py3.11/lib/python3.11/urllib/request.py", line 496, in _call_chain
#     result = func(*args)
#              ^^^^^^^^^^^
#   File "/apps/software/standard/core/jupyterlab/3.6.3-py3.11/lib/python3.11/urllib/request.py", line 1391, in https_open
#     return self.do_open(http.client.HTTPSConnection, req,
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/apps/software/standard/core/jupyterlab/3.6.3-py3.11/lib/python3.11/urllib/request.py", line 1352, in do_open
#     r = h.getresponse()
#         ^^^^^^^^^^^^^^^
#   File "/apps/software/standard/core/jupyterlab/3.6.3-py3.11/lib/python3.11/http/client.py", line 1378, in getresponse
#     response.begin()
#   File "/apps/software/standard/core/jupyterlab/3.6.3-py3.11/lib/python3.11/http/client.py", line 318, in begin
#     version, status, reason = self._read_status()
#                               ^^^^^^^^^^^^^^^^^^^
#   File "/apps/software/standard/core/jupyterlab/3.6.3-py3.11/lib/python3.11/http/client.py", line 279, in _read_status
#     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/apps/software/standard/core/jupyterlab/3.6.3-py3.11/lib/python3.11/socket.py", line 706, in readinto
#     return self._sock.recv_into(b)
#            ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/apps/software/standard/core/jupyterlab/3.6.3-py3.11/lib/python3.11/ssl.py", line 1278, in recv_into
#     return self.read(nbytes, buffer)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/apps/software/standard/core/jupyterlab/3.6.3-py3.11/lib/python3.11/ssl.py", line 1134, in read
#     return self._sslobj.read(len, buffer)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# TimeoutError: The read operation timed out
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/jah9kqn/.local/lib/python3.11/site-packages/imdb/__init__.py", line 848, in update
#     ret = method(mopID)
#           ^^^^^^^^^^^^^
#   File "/home/jah9kqn/.local/lib/python3.11/site-packages/imdb/parser/http/__init__.py", line 481, in get_movie_main
#     cont = self._retrieve(self.urls['movie_main'] % movieID + 'reference')
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/jah9kqn/.local/lib/python3.11/site-packages/imdb/parser/http/__init__.py", line 392, in _retrieve
#     ret = self.urlOpener.retrieve_unicode(url, size=size)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/jah9kqn/.local/lib/python3.11/site-packages/imdb/parser/http/__init__.py", line 261, in retrieve_unicode
#     raise IMDbDataAccessError(
# imdb._exceptions.IMDbDataAccessError: {'errcode': None, 'errmsg': 'None', 'url': 'https://www.imdb.com/title/tt0088580/reference', 'proxy': '', 'exception type': 'IOError', 'original exception': TimeoutError('The read operation timed out')}
# Processing Movies:  91%|█████████▏| 6486/7091 [46:00<3:11:29, 18.99s/it]
# Error for ('0088580', 'http://www.imdb.com/title/tt0088580/usercomments'): {'errcode': None, 'errmsg': 'None', 'url': 'https://www.imdb.com/title/tt0088580/reference', 'proxy': '', 'exception type': 'IOError', 'original exception': TimeoutError('The read operation timed out')}. Retrying (3/3)...
# Processing Movies:  96%|█████████▌| 6799/7091 [46:53<01:45,  2.77it/s]  2025-04-24 18:04:19,056 CRITICAL [imdbpy] /home/jah9kqn/.local/lib/python3.11/site-packages/imdb/_exceptions.py:32: IMDbDataAccessError exception raised; args: ({'errcode': None, 'errmsg': 'None', 'url': 'https://www.imdb.com/title/tt0108467/reference', 'proxy': '', 'exception type': 'IOError', 'original exception': <HTTPError 404: ''>},); kwds: {}
# Traceback (most recent call last):
#   File "/home/jah9kqn/.local/lib/python3.11/site-packages/imdb/parser/http/__init__.py", line 233, in retrieve_unicode
#     response = uopener.open(url)
#                ^^^^^^^^^^^^^^^^^
#   File "/apps/software/standard/core/jupyterlab/3.6.3-py3.11/lib/python3.11/urllib/request.py", line 525, in open
#     response = meth(req, response)
# ...
#     response = uopener.open(url)
#                ^^^^^^^^^^^^^^^^^
#   File "/apps/software/standard/core/jupyterlab/3.6.3-py3.11/lib/python3.11/urllib/request.py", line 525, in open
#     response = meth(req, response)
#                ^^^^^^^^^^^^^^^^^^^
#   File "/apps/software/standard/core/jupyterlab/3.6.3-py3.11/lib/python3.11/urllib/request.py", line 634, in http_response
#     response = self.parent.error(
#                ^^^^^^^^^^^^^^^^^^
#   File "/apps/software/standard/core/jupyterlab/3.6.3-py3.11/lib/python3.11/urllib/request.py", line 563, in error
#     return self._call_chain(*args)
#            ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/apps/software/standard/core/jupyterlab/3.6.3-py3.11/lib/python3.11/urllib/request.py", line 496, in _call_chain
#     result = func(*args)
#              ^^^^^^^^^^^
#   File "/apps/software/standard/core/jupyterlab/3.6.3-py3.11/lib/python3.11/urllib/request.py", line 643, in http_error_default
#     raise HTTPError(req.full_url, code, msg, hdrs, fp)
# urllib.error.HTTPError: HTTP Error 404:
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/jah9kqn/.local/lib/python3.11/site-packages/imdb/__init__.py", line 848, in update
#     ret = method(mopID)
#           ^^^^^^^^^^^^^
#   File "/home/jah9kqn/.local/lib/python3.11/site-packages/imdb/parser/http/__init__.py", line 481, in get_movie_main
#     cont = self._retrieve(self.urls['movie_main'] % movieID + 'reference')
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/jah9kqn/.local/lib/python3.11/site-packages/imdb/parser/http/__init__.py", line 392, in _retrieve
#     ret = self.urlOpener.retrieve_unicode(url, size=size)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/jah9kqn/.local/lib/python3.11/site-packages/imdb/parser/http/__init__.py", line 261, in retrieve_unicode
#     raise IMDbDataAccessError(
# imdb._exceptions.IMDbDataAccessError: {'errcode': None, 'errmsg': 'None', 'url': 'https://www.imdb.com/title/tt0108467/reference', 'proxy': '', 'exception type': 'IOError', 'original exception': <HTTPError 404: ''>}
# Error for ('0108467', 'http://www.imdb.com/title/tt0108467/usercomments'): {'errcode': None, 'errmsg': 'None', 'url': 'https://www.imdb.com/title/tt0108467/reference', 'proxy': '', 'exception type': 'IOError', 'original exception': <HTTPError 404: ''>}. Retrying (1/3)...
# Error for ('0108467', 'http://www.imdb.com/title/tt0108467/usercomments'): {'errcode': None, 'errmsg': 'None', 'url': 'https://www.imdb.com/title/tt0108467/reference', 'proxy': '', 'exception type': 'IOError', 'original exception': <HTTPError 404: ''>}. Retrying (2/3)...
# Error for ('0108467', 'http://www.imdb.com/title/tt0108467/usercomments'): {'errcode': None, 'errmsg': 'None', 'url': 'https://www.imdb.com/title/tt0108467/reference', 'proxy': '', 'exception type': 'IOError', 'original exception': <HTTPError 404: ''>}. Retrying (3/3)...
# Processing Movies:  98%|█████████▊| 6972/7091 [48:03<00:40,  2.91it/s]2025-04-24 18:05:28,681 CRITICAL [imdbpy] /home/jah9kqn/.local/lib/python3.11/site-packages/imdb/_exceptions.py:32: IMDbDataAccessError exception raised; args: ({'errcode': None, 'errmsg': 'None', 'url': 'https://www.imdb.com/title/tt0105228/reference', 'proxy': '', 'exception type': 'IOError', 'original exception': <HTTPError 404: ''>},); kwds: {}
# Traceback (most recent call last):
#   File "/home/jah9kqn/.local/lib/python3.11/site-packages/imdb/parser/http/__init__.py", line 233, in retrieve_unicode
#     response = uopener.open(url)
#                ^^^^^^^^^^^^^^^^^
#   File "/apps/software/standard/core/jupyterlab/3.6.3-py3.11/lib/python3.11/urllib/request.py", line 525, in open
#     response = meth(req, response)
#                ^^^^^^^^^^^^^^^^^^^
#   File "/apps/software/standard/core/jupyterlab/3.6.3-py3.11/lib/python3.11/urllib/request.py", line 634, in http_response
#     response = self.parent.error(
#                ^^^^^^^^^^^^^^^^^^
#   File "/apps/software/standard/core/jupyterlab/3.6.3-py3.11/lib/python3.11/urllib/request.py", line 563, in error
#     return self._call_chain(*args)
#            ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/apps/software/standard/core/jupyterlab/3.6.3-py3.11/lib/python3.11/urllib/request.py", line 496, in _call_chain
#     result = func(*args)
#              ^^^^^^^^^^^
#   File "/apps/software/standard/core/jupyterlab/3.6.3-py3.11/lib/python3.11/urllib/request.py", line 643, in http_error_default
#     raise HTTPError(req.full_url, code, msg, hdrs, fp)
# urllib.error.HTTPError: HTTP Error 404:
# 2025-04-24 18:05:28,683 CRITICAL [imdbpy] /home/jah9kqn/.local/lib/python3.11/site-packages/imdb/__init__.py:850: caught an exception retrieving or parsing "main" info set for mopID "0105228" (accessSystem: http)
# Traceback (most recent call last):
#   File "/home/jah9kqn/.local/lib/python3.11/site-packages/imdb/parser/http/__init__.py", line 233, in retrieve_unicode
#     response = uopener.open(url)
#                ^^^^^^^^^^^^^^^^^
#   File "/apps/software/standard/core/jupyterlab/3.6.3-py3.11/lib/python3.11/urllib/request.py", line 525, in open
#     response = meth(req, response)
#                ^^^^^^^^^^^^^^^^^^^
#   File "/apps/software/standard/core/jupyterlab/3.6.3-py3.11/lib/python3.11/urllib/request.py", line 634, in http_response
#     response = self.parent.error(
#                ^^^^^^^^^^^^^^^^^^
#   File "/apps/software/standard/core/jupyterlab/3.6.3-py3.11/lib/python3.11/urllib/request.py", line 563, in error
#     return self._call_chain(*args)
#            ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/apps/software/standard/core/jupyterlab/3.6.3-py3.11/lib/python3.11/urllib/request.py", line 496, in _call_chain
#     result = func(*args)
#              ^^^^^^^^^^^
#   File "/apps/software/standard/core/jupyterlab/3.6.3-py3.11/lib/python3.11/urllib/request.py", line 643, in http_error_default
#     raise HTTPError(req.full_url, code, msg, hdrs, fp)
# urllib.error.HTTPError: HTTP Error 404:
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/jah9kqn/.local/lib/python3.11/site-packages/imdb/__init__.py", line 848, in update
#     ret = method(mopID)
#           ^^^^^^^^^^^^^
#   File "/home/jah9kqn/.local/lib/python3.11/site-packages/imdb/parser/http/__init__.py", line 481, in get_movie_main
#     cont = self._retrieve(self.urls['movie_main'] % movieID + 'reference')
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/jah9kqn/.local/lib/python3.11/site-packages/imdb/parser/http/__init__.py", line 392, in _retrieve
#     ret = self.urlOpener.retrieve_unicode(url, size=size)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/jah9kqn/.local/lib/python3.11/site-packages/imdb/parser/http/__init__.py", line 261, in retrieve_unicode
#     raise IMDbDataAccessError(
# imdb._exceptions.IMDbDataAccessError: {'errcode': None, 'errmsg': 'None', 'url': 'https://www.imdb.com/title/tt0105228/reference', 'proxy': '', 'exception type': 'IOError', 'original exception': <HTTPError 404: ''>}
# 2025-04-24 18:05:28,755 CRITICAL [imdbpy] /home/jah9kqn/.local/lib/python3.11/site-packages/imdb/_exceptions.py:32: IMDbDataAccessError exception raised; args: ({'errcode': None, 'errmsg': 'None', 'url': 'https://www.imdb.com/title/tt0105228/reference', 'proxy': '', 'exception type': 'IOError', 'original exception': <HTTPError 404: ''>},); kwds: {}
# Traceback (most recent call last):
#   File "/home/jah9kqn/.local/lib/python3.11/site-packages/imdb/parser/http/__init__.py", line 233, in retrieve_unicode
#     response = uopener.open(url)
#                ^^^^^^^^^^^^^^^^^
#   File "/apps/software/standard/core/jupyterlab/3.6.3-py3.11/lib/python3.11/urllib/request.py", line 525, in open
#     response = meth(req, response)
#                ^^^^^^^^^^^^^^^^^^^
#   File "/apps/software/standard/core/jupyterlab/3.6.3-py3.11/lib/python3.11/urllib/request.py", line 634, in http_response
#     response = self.parent.error(
#                ^^^^^^^^^^^^^^^^^^
#   File "/apps/software/standard/core/jupyterlab/3.6.3-py3.11/lib/python3.11/urllib/request.py", line 563, in error
#     return self._call_chain(*args)
#            ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/apps/software/standard/core/jupyterlab/3.6.3-py3.11/lib/python3.11/urllib/request.py", line 496, in _call_chain
#     result = func(*args)
#              ^^^^^^^^^^^
#   File "/apps/software/standard/core/jupyterlab/3.6.3-py3.11/lib/python3.11/urllib/request.py", line 643, in http_error_default
#     raise HTTPError(req.full_url, code, msg, hdrs, fp)
# urllib.error.HTTPError: HTTP Error 404:
# 2025-04-24 18:05:28,755 CRITICAL [imdbpy] /home/jah9kqn/.local/lib/python3.11/site-packages/imdb/__init__.py:850: caught an exception retrieving or parsing "main" info set for mopID "0105228" (accessSystem: http)
# Traceback (most recent call last):
#   File "/home/jah9kqn/.local/lib/python3.11/site-packages/imdb/parser/http/__init__.py", line 233, in retrieve_unicode
#     response = uopener.open(url)
#                ^^^^^^^^^^^^^^^^^
#   File "/apps/software/standard/core/jupyterlab/3.6.3-py3.11/lib/python3.11/urllib/request.py", line 525, in open
#     response = meth(req, response)
#                ^^^^^^^^^^^^^^^^^^^
#   File "/apps/software/standard/core/jupyterlab/3.6.3-py3.11/lib/python3.11/urllib/request.py", line 634, in http_response
#     response = self.parent.error(
#                ^^^^^^^^^^^^^^^^^^
#   File "/apps/software/standard/core/jupyterlab/3.6.3-py3.11/lib/python3.11/urllib/request.py", line 563, in error
#     return self._call_chain(*args)
#            ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/apps/software/standard/core/jupyterlab/3.6.3-py3.11/lib/python3.11/urllib/request.py", line 496, in _call_chain
#     result = func(*args)
#              ^^^^^^^^^^^
#   File "/apps/software/standard/core/jupyterlab/3.6.3-py3.11/lib/python3.11/urllib/request.py", line 643, in http_error_default
#     raise HTTPError(req.full_url, code, msg, hdrs, fp)
# urllib.error.HTTPError: HTTP Error 404:
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/jah9kqn/.local/lib/python3.11/site-packages/imdb/__init__.py", line 848, in update
#     ret = method(mopID)
#           ^^^^^^^^^^^^^
#   File "/home/jah9kqn/.local/lib/python3.11/site-packages/imdb/parser/http/__init__.py", line 481, in get_movie_main
#     cont = self._retrieve(self.urls['movie_main'] % movieID + 'reference')
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/jah9kqn/.local/lib/python3.11/site-packages/imdb/parser/http/__init__.py", line 392, in _retrieve
#     ret = self.urlOpener.retrieve_unicode(url, size=size)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/jah9kqn/.local/lib/python3.11/site-packages/imdb/parser/http/__init__.py", line 261, in retrieve_unicode
#     raise IMDbDataAccessError(
# imdb._exceptions.IMDbDataAccessError: {'errcode': None, 'errmsg': 'None', 'url': 'https://www.imdb.com/title/tt0105228/reference', 'proxy': '', 'exception type': 'IOError', 'original exception': <HTTPError 404: ''>}
# 2025-04-24 18:05:28,845 CRITICAL [imdbpy] /home/jah9kqn/.local/lib/python3.11/site-packages/imdb/_exceptions.py:32: IMDbDataAccessError exception raised; args: ({'errcode': None, 'errmsg': 'None', 'url': 'https://www.imdb.com/title/tt0105228/reference', 'proxy': '', 'exception type': 'IOError', 'original exception': <HTTPError 404: ''>},); kwds: {}
# Traceback (most recent call last):
#   File "/home/jah9kqn/.local/lib/python3.11/site-packages/imdb/parser/http/__init__.py", line 233, in retrieve_unicode
#     response = uopener.open(url)
#                ^^^^^^^^^^^^^^^^^
#   File "/apps/software/standard/core/jupyterlab/3.6.3-py3.11/lib/python3.11/urllib/request.py", line 525, in open
#     response = meth(req, response)
#                ^^^^^^^^^^^^^^^^^^^
#   File "/apps/software/standard/core/jupyterlab/3.6.3-py3.11/lib/python3.11/urllib/request.py", line 634, in http_response
#     response = self.parent.error(
#                ^^^^^^^^^^^^^^^^^^
#   File "/apps/software/standard/core/jupyterlab/3.6.3-py3.11/lib/python3.11/urllib/request.py", line 563, in error
#     return self._call_chain(*args)
#            ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/apps/software/standard/core/jupyterlab/3.6.3-py3.11/lib/python3.11/urllib/request.py", line 496, in _call_chain
#     result = func(*args)
#              ^^^^^^^^^^^
#   File "/apps/software/standard/core/jupyterlab/3.6.3-py3.11/lib/python3.11/urllib/request.py", line 643, in http_error_default
#     raise HTTPError(req.full_url, code, msg, hdrs, fp)
# urllib.error.HTTPError: HTTP Error 404:
# 2025-04-24 18:05:28,846 CRITICAL [imdbpy] /home/jah9kqn/.local/lib/python3.11/site-packages/imdb/__init__.py:850: caught an exception retrieving or parsing "main" info set for mopID "0105228" (accessSystem: http)
# Traceback (most recent call last):
#   File "/home/jah9kqn/.local/lib/python3.11/site-packages/imdb/parser/http/__init__.py", line 233, in retrieve_unicode
#     response = uopener.open(url)
#                ^^^^^^^^^^^^^^^^^
#   File "/apps/software/standard/core/jupyterlab/3.6.3-py3.11/lib/python3.11/urllib/request.py", line 525, in open
#     response = meth(req, response)
#                ^^^^^^^^^^^^^^^^^^^
#   File "/apps/software/standard/core/jupyterlab/3.6.3-py3.11/lib/python3.11/urllib/request.py", line 634, in http_response
#     response = self.parent.error(
#                ^^^^^^^^^^^^^^^^^^
#   File "/apps/software/standard/core/jupyterlab/3.6.3-py3.11/lib/python3.11/urllib/request.py", line 563, in error
#     return self._call_chain(*args)
#            ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/apps/software/standard/core/jupyterlab/3.6.3-py3.11/lib/python3.11/urllib/request.py", line 496, in _call_chain
#     result = func(*args)
#              ^^^^^^^^^^^
#   File "/apps/software/standard/core/jupyterlab/3.6.3-py3.11/lib/python3.11/urllib/request.py", line 643, in http_error_default
#     raise HTTPError(req.full_url, code, msg, hdrs, fp)
# urllib.error.HTTPError: HTTP Error 404:
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/jah9kqn/.local/lib/python3.11/site-packages/imdb/__init__.py", line 848, in update
#     ret = method(mopID)
#           ^^^^^^^^^^^^^
#   File "/home/jah9kqn/.local/lib/python3.11/site-packages/imdb/parser/http/__init__.py", line 481, in get_movie_main
#     cont = self._retrieve(self.urls['movie_main'] % movieID + 'reference')
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/jah9kqn/.local/lib/python3.11/site-packages/imdb/parser/http/__init__.py", line 392, in _retrieve
#     ret = self.urlOpener.retrieve_unicode(url, size=size)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/jah9kqn/.local/lib/python3.11/site-packages/imdb/parser/http/__init__.py", line 261, in retrieve_unicode
#     raise IMDbDataAccessError(
# imdb._exceptions.IMDbDataAccessError: {'errcode': None, 'errmsg': 'None', 'url': 'https://www.imdb.com/title/tt0105228/reference', 'proxy': '', 'exception type': 'IOError', 'original exception': <HTTPError 404: ''>}
# Error for ('0105228', 'http://www.imdb.com/title/tt0105228/usercomments'): {'errcode': None, 'errmsg': 'None', 'url': 'https://www.imdb.com/title/tt0105228/reference', 'proxy': '', 'exception type': 'IOError', 'original exception': <HTTPError 404: ''>}. Retrying (1/3)...
# Error for ('0105228', 'http://www.imdb.com/title/tt0105228/usercomments'): {'errcode': None, 'errmsg': 'None', 'url': 'https://www.imdb.com/title/tt0105228/reference', 'proxy': '', 'exception type': 'IOError', 'original exception': <HTTPError 404: ''>}. Retrying (2/3)...
# Error for ('0105228', 'http://www.imdb.com/title/tt0105228/usercomments'): {'errcode': None, 'errmsg': 'None', 'url': 'https://www.imdb.com/title/tt0105228/reference', 'proxy': '', 'exception type': 'IOError', 'original exception': <HTTPError 404: ''>}. Retrying (3/3)...
# Processing Movies: 100%|██████████| 7091/7091 [48:52<00:00,  2.42it/s]

# %%
pd.DataFrame(movie_results).to_csv('../data/movie_results.csv', index=False)
